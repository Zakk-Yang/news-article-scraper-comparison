 'https://www.nytimes.com/2024/10/28/opinion/washington-post-la-times-endorsement.html',
 'https://www.nytimes.com/2024/10/28/opinion/trump-rally-msg-racism.html',
 'https://www.nytimes.com/2024/10/28/opinion/japan-liberal-democratic-party.html',
 'https://www.nytimes.com/2024/06/23/opinion/ceo-trump-republican-support.html',
 'https://www.nytimes.com/2024/10/28/opinion/forced-arbitration-uber-disney.html',
 'https://www.nytimes.com/live/2024/10/22/opinion/thepoint/onstage-in-new-york-trump-gazes-lovingly-at-his-reflection',
 'https://www.nytimes.com/2024/10/28/opinion/gop-anti-trans-advertising-harris.html',
 'https://www.nytimes.com/2024/10/27/opinion/ted-cruz-texas-senate-race.html',
 'https://www.nytimes.com/2024/10/27/opinion/never-trump-maga-evangelicals.html',
 'https://www.nytimes.com/2024/10/28/insider/in-the-race-for-congress-a-reporter-starts-with-a-blank-notebook.html',
 'https://www.nytimes.com/2024/10/28/business/media/washington-post-endorsement-editorial-board.html',
 'https://www.nytimes.com/2024/10/28/world/middleeast/iran-jamshid-sharmahd-narges-mohammadi.html',
 'https://www.nytimes.com/2024/10/28/world/europe/british-labour-lawmaker-punch-video.html',
 'https://www.nytimes.com/2024/10/28/world/europe/uk-cheese-theft-scam.html',
 'https://www.nytimes.com/athletic/5867806/2024/10/25/jayden-daniels-washington-commanders-hope-nfl/',
 'https://www.nytimes.com/athletic/5854102/2024/10/24/uncrustables-nfl/',
 'https://www.nytimes.com/athletic/5870030/2024/10/25/ohtani-japan-dodgers-yankees-world-series/',
 'https://www.nytimes.com/athletic/5869794/2024/10/25/anthony-davis-zion-williamson-and-9-other-nba-players-ready-for-big-years/',
 'https://www.nytimes.com/athletic/5870864/2024/10/24/amir-abdur-rahim-death-usf-coach/',
 'https://www.nytimes.com/athletic/5867884/2024/10/24/ole-miss-college-football-playoff-nil/',
 'https://www.nytimes.com/2024/10/25/t-magazine/cornwall-england-hotels-restaurants-guide.html',
 'https://www.nytimes.com/international/section/business/media',
 'https://www.nytimes.com/2024/10/27/business/media/washington-post-president-endorsement.html',
 'https://www.nytimes.com/2024/10/28/business/dealbook/ceos-trump-win.html',
 'https://www.nytimes.com/2024/10/27/business/market-history-elections-disasters.html',
 'https://www.nytimes.com/2024/10/28/business/japan-economy-election.html',
 'https://www.nytimes.com/2024/10/26/business/media/jessica-tarlov-the-five-fox-news.html',
 'https://www.nytimes.com/2024/10/28/business/uk-budget-taxes.html',
 'https://www.nytimes.com/2024/10/27/business/media/tom-jarriel-dead.html',
 'https://www.nytimes.com/2024/10/28/business/waymo-investment-robot-taxis.html',
 'https://www.nytimes.com/2024/10/28/us/politics/biden-affordable-housing-programs.html',
 'https://www.nytimes.com/2024/10/28/us/healthcare-taxpayer-money-insurance.html',
 'https://www.nytimes.com/2024/10/27/health/mcdonalds-ecoli-quarter-pounders.html',
 'https://www.nytimes.com/2024/10/27/movies/california-governor-newsom-film-tax-credits.html'
]

def scrape_with_newspaper(url):
    article = Article(url)
    article.download()
    article.parse()
    return article.text

def scrape_with_newsplease(url):
    article = NewsPlease.from_url(url)
    return article.maintext if article else None

def time_scraper(scraper_func, urls):
    start_time = time.time()
    for url in urls:
        try:
            content = scraper_func(url)
            assert content  # Check if content was extracted
        except Exception as e:
            print(f"Error scraping {url} with {scraper_func.__name__}: {e}")
    return time.time() - start_time

# Test Newspaper4k
newspaper_time = time_scraper(scrape_with_newspaper, urls)
print(f"Newspaper4k total time for {len(urls)} URLs: {newspaper_time:.2f} seconds")

# Test news-please
newsplease_time = time_scraper(scrape_with_newsplease, urls)
print(f"news-please total time for {len(urls)} URLs: {newsplease_time:.2f} seconds")

# Comparison
if newspaper_time < newsplease_time:
    print("Newspaper4k is faster")
else:
    print("news-please is faster")
